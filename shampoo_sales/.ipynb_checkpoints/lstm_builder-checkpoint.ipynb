# %%
# %load_ext jupyternotify

# %%
# Silence TensorFlow warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
import tensorflow as tf

# %%
# Import Statements
#from __future__ import absolute_import
from pandas import DataFrame, Series, concat, read_csv, datetime
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.externals import joblib
from keras.models import Sequential
from keras.layers import Dense, LSTM, TimeDistributed
from keras.callbacks import LambdaCallback, History
from math import sqrt
from matplotlib import pyplot
import numpy
import pickle

# %%
# date-time parsing function for loading the dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return Series(diff)

# %%
# invert differenced value
def inverse_difference(history, yhat, interval=1):
    return yhat + history[-interval]

# %%
# scale train and test data to [-1, 1]
def scale(train, test):
    # fit scaler
    '''scaler = MinMaxScaler(feature_range=(-1, 1))'''
    scaler = StandardScaler()
    scaler = scaler.fit(train)
    # transform train
    train = train.reshape(train.shape[0], train.shape[1])
    train_scaled = scaler.transform(train)
    # transform test
    test = test.reshape(test.shape[0], test.shape[1])
    test_scaled = scaler.transform(test)
    return scaler, train_scaled, test_scaled

# %%
# fit an LSTM network to training data
def fit_lstm(train, test, batch_size, nb_epoch, neurons):
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])

    x_test, y_test = test[:, 0:-1], test[:, -1]
    x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])

    history = History()

    print(X.shape)
    print(x_test.shape)
    model = Sequential()
    model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=False, return_sequences=True))
    model.add(Dense(2*neurons, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(neurons, activation='relu'))
    model.add(LSTM(neurons, stateful=True, return_sequences=False))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    h = model.fit(X, y, epochs=nb_epoch, batch_size=batch_size, verbose=1, shuffle=False, validation_data=(x_test, y_test), callbacks=[history])
    return model, h

# %%
# load dataset
series = read_csv('./shampoo_sales_data.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)

# transform data to be stationary
raw_values = series.values
diff_values = difference(raw_values, 1)

# %%
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# %%
# split data into train and test-sets, saving results
train, test = supervised_values[0:-12], supervised_values[-12:]
numpy.savetxt('train_df.csv', train, delimiter=',')
numpy.savetxt('test_df.csv', test, delimiter=',')

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# Save scaler object and scaled data
joblib.dump(scaler, 'lstm_scaler.pkl')
numpy.savetxt('train_scaled_df.csv', train_scaled, delimiter=',')
numpy.savetxt('test_scaled_df.csv', test_scaled, delimiter=',')

print(train_scaled.shape, test_scaled.shape)
# Out:
# (23, 2) (12, 2)

# %%
# %%notify
# # fit the model
# lstm_model, hist = fit_lstm(train_scaled, test_scaled, 1, 256, 8)
# Out:
# (23, 1, 1)
# (12, 1, 1)
# Train on 23 samples, validate on 12 samples
# Epoch 1/256
# 23/23 [==============================] - 1s 37ms/step - loss: 1.2443 - val_loss: 2.2984
# Epoch 2/256
# 23/23 [==============================] - 0s 13ms/step - loss: 1.2293 - val_loss: 2.2865
# Epoch 3/256
# 23/23 [==============================] - 0s 13ms/step - loss: 1.2016 - val_loss: 2.2625
# Epoch 4/256
# 23/23 [==============================] - 0s 12ms/step - loss: 1.1460 - val_loss: 2.2309
# Epoch 5/256
# 23/23 [==============================] - 0s 13ms/step - loss: 1.0746 - val_loss: 2.2141
# Epoch 6/256
# 23/23 [==============================] - 0s 13ms/step - loss: 1.0261 - val_loss: 2.2063
# Epoch 7/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9988 - val_loss: 2.1954
# Epoch 8/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.9808 - val_loss: 2.1841
# Epoch 9/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9664 - val_loss: 2.1718
# Epoch 10/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9544 - val_loss: 2.1535
# Epoch 11/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.9425 - val_loss: 2.1219
# Epoch 12/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.9268 - val_loss: 2.0695
# Epoch 13/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.9061 - val_loss: 1.9932
# Epoch 14/256
# 23/23 [==============================] - 0s 17ms/step - loss: 0.8831 - val_loss: 1.9358
# Epoch 15/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8741 - val_loss: 1.9220
# Epoch 16/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8576 - val_loss: 1.9151
# Epoch 17/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8447 - val_loss: 1.9126
# Epoch 18/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8362 - val_loss: 1.9116
# Epoch 19/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.8316 - val_loss: 1.9111
# Epoch 20/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8285 - val_loss: 1.9100
# Epoch 21/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8263 - val_loss: 1.9088
# Epoch 22/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.8243 - val_loss: 1.9074
# Epoch 23/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8225 - val_loss: 1.9061
# Epoch 24/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.8210 - val_loss: 1.9048
# Epoch 25/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.8196 - val_loss: 1.9034
# Epoch 26/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8179 - val_loss: 1.9020
# Epoch 27/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8162 - val_loss: 1.9002
# Epoch 28/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8140 - val_loss: 1.8986
# Epoch 29/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8130 - val_loss: 1.8970
# Epoch 30/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8111 - val_loss: 1.8953
# Epoch 31/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8086 - val_loss: 1.8934
# Epoch 32/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.8093 - val_loss: 1.8927
# Epoch 33/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8067 - val_loss: 1.8913
# Epoch 34/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8058 - val_loss: 1.8903
# Epoch 35/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8044 - val_loss: 1.8888
# Epoch 36/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8036 - val_loss: 1.8872
# Epoch 37/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8033 - val_loss: 1.8858
# Epoch 38/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8013 - val_loss: 1.8826
# Epoch 39/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.8017 - val_loss: 1.8815
# Epoch 40/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7993 - val_loss: 1.8792
# Epoch 41/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7984 - val_loss: 1.8769
# Epoch 42/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7975 - val_loss: 1.8753
# Epoch 43/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7948 - val_loss: 1.8707
# Epoch 44/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7961 - val_loss: 1.8693
# Epoch 45/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7929 - val_loss: 1.8634
# Epoch 46/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7967 - val_loss: 1.8648
# Epoch 47/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7941 - val_loss: 1.8630
# Epoch 48/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7940 - val_loss: 1.8614
# Epoch 49/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7949 - val_loss: 1.8644
# Epoch 50/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7929 - val_loss: 1.8629
# Epoch 51/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7931 - val_loss: 1.8698
# Epoch 52/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7873 - val_loss: 1.8642
# Epoch 53/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7875 - val_loss: 1.8745
# Epoch 54/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7840 - val_loss: 1.8746
# Epoch 55/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7842 - val_loss: 1.8875
# Epoch 56/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7819 - val_loss: 1.8821
# Epoch 57/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7780 - val_loss: 1.9118
# Epoch 58/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7689 - val_loss: 1.9042
# Epoch 59/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.7741 - val_loss: 1.8959
# Epoch 60/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7680 - val_loss: 1.9203
# Epoch 61/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7704 - val_loss: 1.8645
# Epoch 62/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7955 - val_loss: 1.8762
# Epoch 63/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7748 - val_loss: 1.9744
# Epoch 64/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7932 - val_loss: 1.8892
# Epoch 65/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7868 - val_loss: 1.8749
# Epoch 66/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7850 - val_loss: 1.8771
# Epoch 67/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7825 - val_loss: 1.8840
# Epoch 68/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7817 - val_loss: 1.8837
# Epoch 69/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7866 - val_loss: 1.8732
# Epoch 70/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7794 - val_loss: 1.8721
# Epoch 71/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7747 - val_loss: 1.9028
# Epoch 72/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7766 - val_loss: 1.9261
# Epoch 73/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7807 - val_loss: 1.9158
# Epoch 74/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7644 - val_loss: 1.9792
# Epoch 75/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7644 - val_loss: 2.0792
# Epoch 76/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7930 - val_loss: 2.0908
# Epoch 77/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7947 - val_loss: 2.0566
# Epoch 78/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7771 - val_loss: 1.9697
# Epoch 79/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7809 - val_loss: 1.9608
# Epoch 80/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7974 - val_loss: 2.0115
# Epoch 81/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.8064 - val_loss: 2.0475
# Epoch 82/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7952 - val_loss: 2.0845
# Epoch 83/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7897 - val_loss: 1.9340
# Epoch 84/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7868 - val_loss: 1.7823
# Epoch 85/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7930 - val_loss: 1.7903
# Epoch 86/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7865 - val_loss: 1.9006
# Epoch 87/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7994 - val_loss: 1.9061
# Epoch 88/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8114 - val_loss: 1.8935
# Epoch 89/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8064 - val_loss: 1.8912
# Epoch 90/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7960 - val_loss: 1.9147
# Epoch 91/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7757 - val_loss: 1.9799
# Epoch 92/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7656 - val_loss: 1.9431
# Epoch 93/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7630 - val_loss: 1.8158
# Epoch 94/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7749 - val_loss: 1.7481
# Epoch 95/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7818 - val_loss: 1.7645
# Epoch 96/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7675 - val_loss: 1.9291
# Epoch 97/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8090 - val_loss: 2.0063
# Epoch 98/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.8191 - val_loss: 1.9033
# Epoch 99/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7909 - val_loss: 1.8475
# Epoch 100/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7693 - val_loss: 1.8111
# Epoch 101/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7743 - val_loss: 1.8182
# Epoch 102/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7686 - val_loss: 1.8885
# Epoch 103/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7920 - val_loss: 1.8949
# Epoch 104/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7975 - val_loss: 1.8748
# Epoch 105/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7976 - val_loss: 1.8569
# Epoch 106/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7956 - val_loss: 1.8411
# Epoch 107/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7939 - val_loss: 1.8339
# Epoch 108/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7926 - val_loss: 1.8254
# Epoch 109/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7911 - val_loss: 1.8175
# Epoch 110/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7899 - val_loss: 1.8111
# Epoch 111/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7887 - val_loss: 1.8056
# Epoch 112/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7878 - val_loss: 1.8008
# Epoch 113/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7869 - val_loss: 1.7967
# Epoch 114/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7859 - val_loss: 1.7925
# Epoch 115/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7850 - val_loss: 1.7887
# Epoch 116/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7842 - val_loss: 1.7857
# Epoch 117/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7834 - val_loss: 1.7827
# Epoch 118/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7830 - val_loss: 1.7806
# Epoch 119/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7819 - val_loss: 1.7781
# Epoch 120/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7815 - val_loss: 1.7765
# Epoch 121/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7798 - val_loss: 1.7777
# Epoch 122/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7768 - val_loss: 1.7853
# Epoch 123/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7733 - val_loss: 1.7934
# Epoch 124/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7746 - val_loss: 1.8238
# Epoch 125/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7787 - val_loss: 1.8420
# Epoch 126/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7789 - val_loss: 1.8424
# Epoch 127/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7771 - val_loss: 1.8424
# Epoch 128/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7730 - val_loss: 1.8515
# Epoch 129/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7694 - val_loss: 1.8615
# Epoch 130/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7673 - val_loss: 1.8689
# Epoch 131/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7676 - val_loss: 1.8858
# Epoch 132/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7647 - val_loss: 1.9001
# Epoch 133/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7700 - val_loss: 1.9053
# Epoch 134/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7683 - val_loss: 1.9137
# Epoch 135/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7672 - val_loss: 1.9081
# Epoch 136/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7676 - val_loss: 1.8920
# Epoch 137/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7663 - val_loss: 1.8718
# Epoch 138/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7658 - val_loss: 1.8445
# Epoch 139/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7667 - val_loss: 1.8129
# Epoch 140/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7676 - val_loss: 1.7861
# Epoch 141/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.7788 - val_loss: 1.7689
# Epoch 142/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7845 - val_loss: 1.7646
# Epoch 143/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7853 - val_loss: 1.7636
# Epoch 144/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7839 - val_loss: 1.7631
# Epoch 145/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7842 - val_loss: 1.7640
# Epoch 146/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.7783 - val_loss: 1.7660
# Epoch 147/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7727 - val_loss: 1.7679
# Epoch 148/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7687 - val_loss: 1.7679
# Epoch 149/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7680 - val_loss: 1.7680
# Epoch 150/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7675 - val_loss: 1.7683
# Epoch 151/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7673 - val_loss: 1.7686
# Epoch 152/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7673 - val_loss: 1.7687
# Epoch 153/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7674 - val_loss: 1.7682
# Epoch 154/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7675 - val_loss: 1.7676
# Epoch 155/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7676 - val_loss: 1.7670
# Epoch 156/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7675 - val_loss: 1.7664
# Epoch 157/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7674 - val_loss: 1.7658
# Epoch 158/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7673 - val_loss: 1.7654
# Epoch 159/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7673 - val_loss: 1.7649
# Epoch 160/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7672 - val_loss: 1.7644
# Epoch 161/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7671 - val_loss: 1.7638
# Epoch 162/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7669 - val_loss: 1.7633
# Epoch 163/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7667 - val_loss: 1.7628
# Epoch 164/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7664 - val_loss: 1.7623
# Epoch 165/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7660 - val_loss: 1.7619
# Epoch 166/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7657 - val_loss: 1.7615
# Epoch 167/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7653 - val_loss: 1.7611
# Epoch 168/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7650 - val_loss: 1.7607
# Epoch 169/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7647 - val_loss: 1.7603
# Epoch 170/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7643 - val_loss: 1.7599
# Epoch 171/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7639 - val_loss: 1.7592
# Epoch 172/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7639 - val_loss: 1.7590
# Epoch 173/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7634 - val_loss: 1.7585
# Epoch 174/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7634 - val_loss: 1.7580
# Epoch 175/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7633 - val_loss: 1.7576
# Epoch 176/256
# 23/23 [==============================] - ETA: 0s - loss: 0.798 - 0s 9ms/step - loss: 0.7641 - val_loss: 1.7586
# Epoch 177/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7630 - val_loss: 1.7573
# Epoch 178/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7628 - val_loss: 1.7568
# Epoch 179/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7626 - val_loss: 1.7568
# Epoch 180/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7629 - val_loss: 1.7554
# Epoch 181/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7627 - val_loss: 1.7558
# Epoch 182/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7622 - val_loss: 1.7548
# Epoch 183/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7622 - val_loss: 1.7548
# Epoch 184/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7623 - val_loss: 1.7540
# Epoch 185/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7615 - val_loss: 1.7538
# Epoch 186/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7615 - val_loss: 1.7536
# Epoch 187/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7617 - val_loss: 1.7527
# Epoch 188/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7614 - val_loss: 1.7537
# Epoch 189/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7617 - val_loss: 1.7537
# Epoch 190/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7614 - val_loss: 1.7575
# Epoch 191/256
# 23/23 [==============================] - 0s 17ms/step - loss: 0.7615 - val_loss: 1.7706
# Epoch 192/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7590 - val_loss: 1.8262
# Epoch 193/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7600 - val_loss: 1.9150
# Epoch 194/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7636 - val_loss: 1.9535
# Epoch 195/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7850 - val_loss: 1.9633
# Epoch 196/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7925 - val_loss: 1.9510
# Epoch 197/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7799 - val_loss: 1.9587
# Epoch 198/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7879 - val_loss: 1.9730
# Epoch 199/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7882 - val_loss: 1.9701
# Epoch 200/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7896 - val_loss: 1.9391
# Epoch 201/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7641 - val_loss: 1.9374
# Epoch 202/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7663 - val_loss: 1.9351
# Epoch 203/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7569 - val_loss: 1.8880
# Epoch 204/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7544 - val_loss: 1.8603
# Epoch 205/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7592 - val_loss: 1.8196
# Epoch 206/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7564 - val_loss: 1.7905
# Epoch 207/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7575 - val_loss: 1.7799
# Epoch 208/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7594 - val_loss: 1.7686
# Epoch 209/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7600 - val_loss: 1.7637
# Epoch 210/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7610 - val_loss: 1.7619
# Epoch 211/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7610 - val_loss: 1.7641
# Epoch 212/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7602 - val_loss: 1.7776
# Epoch 213/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7589 - val_loss: 1.8109
# Epoch 214/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7550 - val_loss: 1.8689
# Epoch 215/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7542 - val_loss: 1.9169
# Epoch 216/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7588 - val_loss: 1.9421
# Epoch 217/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7687 - val_loss: 1.9444
# Epoch 218/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7684 - val_loss: 1.9416
# Epoch 219/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7680 - val_loss: 1.9273
# Epoch 220/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7571 - val_loss: 1.9189
# Epoch 221/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7585 - val_loss: 1.8940
# Epoch 222/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7540 - val_loss: 1.8541
# Epoch 223/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7546 - val_loss: 1.8229
# Epoch 224/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7555 - val_loss: 1.7837
# Epoch 225/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7567 - val_loss: 1.7633
# Epoch 226/256
# 23/23 [==============================] - 0s 9ms/step - loss: 0.7601 - val_loss: 1.7484
# Epoch 227/256
# 23/23 [==============================] - 0s 10ms/step - loss: 0.7615 - val_loss: 1.7388
# Epoch 228/256
# 23/23 [==============================] - 0s 14ms/step - loss: 0.7623 - val_loss: 1.7386
# Epoch 229/256
# 23/23 [==============================] - 0s 19ms/step - loss: 0.7623 - val_loss: 1.7390
# Epoch 230/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7624 - val_loss: 1.7516
# Epoch 231/256
# 23/23 [==============================] - 0s 16ms/step - loss: 0.7571 - val_loss: 1.8143
# Epoch 232/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7527 - val_loss: 1.9149
# Epoch 233/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7663 - val_loss: 1.9434
# Epoch 234/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7765 - val_loss: 1.9515
# Epoch 235/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7956 - val_loss: 1.9432
# Epoch 236/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7760 - val_loss: 1.9466
# Epoch 237/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7897 - val_loss: 1.9423
# Epoch 238/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7744 - val_loss: 1.9280
# Epoch 239/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7638 - val_loss: 1.9423
# Epoch 240/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7787 - val_loss: 1.9180
# Epoch 241/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7579 - val_loss: 1.9132
# Epoch 242/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7574 - val_loss: 1.9127
# Epoch 243/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7555 - val_loss: 1.8823
# Epoch 244/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7530 - val_loss: 1.8583
# Epoch 245/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7526 - val_loss: 1.8317
# Epoch 246/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7528 - val_loss: 1.8136
# Epoch 247/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7529 - val_loss: 1.7913
# Epoch 248/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7539 - val_loss: 1.7620
# Epoch 249/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7572 - val_loss: 1.7605
# Epoch 250/256
# 23/23 [==============================] - 0s 15ms/step - loss: 0.7598 - val_loss: 1.7515
# Epoch 251/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7619 - val_loss: 1.7512
# Epoch 252/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7616 - val_loss: 1.7632
# Epoch 253/256
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7603 - val_loss: 1.7911
# Epoch 254/256
# 23/23 [==============================] - 0s 11ms/step - loss: 0.7568 - val_loss: 1.8424
# Epoch 255/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7514 - val_loss: 1.9076
# Epoch 256/256
# 23/23 [==============================] - 0s 13ms/step - loss: 0.7595 - val_loss: 1.9286

# %%
# forecast the entire training dataset to build up state for forecasting
train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
lstm_model.predict(train_reshaped, batch_size=1)
# Out:
# array([[  1.14889222e-03],
#        [  4.14664090e-01],
#        [  1.04069861e-03],
#        [  3.38487893e-01],
#        [  9.62449994e-04],
#        [  8.10564030e-03],
#        [  5.99552179e-04],
#        [  2.80909380e-03],
#        [  4.81603965e-02],
#        [  7.42009342e-01],
#        [  2.44079763e-03],
#        [  7.19859958e-01],
#        [  5.31214941e-03],
#        [  6.79030299e-01],
#        [  2.71259807e-03],
#        [  6.96812465e-04],
#        [  5.58013856e-01],
#        [  1.34018192e-03],
#        [  5.42357624e-01],
#        [  1.24095089e-03],
#        [  3.23404670e-02],
#        [  7.85897311e-04],
#        [  5.62866092e-01]], dtype=float32)

# %%
# Save model
# serialize model to JSON
model_json = lstm_model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
lstm_model.save_weights("model.h5")
print("Saved model to disk")

with open('model_history.pkl', 'wb') as file_pi:
        pickle.dump(hist.history, file_pi)
# Out:
# Saved model to disk

# %%
# %notify -m 'Notebook has finished running.'
